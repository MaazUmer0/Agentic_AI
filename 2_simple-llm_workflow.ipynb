# %%
from langgraph.graph import StateGraph ,START, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# %%
model = ChatOpenAI()

# %%
class llm_state(TypedDict):
    question : str
    answer : str

# %%
def llm_qa(state: llm_state)-> llm_state:
    # extract question
    question = state ['question']
    
    # form prompt
    prompt= f'answer the promt {question}'
    
    # ask form llm
    answer = model.invoke(prompt).content
    
    #answer the prompt
    state ['answer']= answer
    
    return state

# %%
graph = StateGraph(llm_state)

graph.add_node('llm_qa', llm_qa)

graph.add_edge(START, 'llm_qa')
graph.add_edge("llm_qa", END)

workflow = graph.compile()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 graph = StateGraph(llm_state)
# ----> 3 graph.add_node('llm_qa', llm_qa)
#       5 graph.add_edge(START, 'llm_qa')
#       6 graph.add_edge("llm_qa", END)
#
# NameError: name 'llm_qa' is not defined

# %%
iniial = {}
output = workflow.invoke(initial)
print(output)
